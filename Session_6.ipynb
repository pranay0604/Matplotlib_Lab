# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"eda_employee_dataset.xls")

# %%
df
# Out:
#      employee_id   age  gender department  experience_years    salary  \
# 0              1  59.0  Female    Finance                13   52127.0
# 1              2   NaN    Male      Sales                15   30141.0
# 2              3  35.0    Male         HR                 0   53884.0
# 3              4  28.0  Female         HR                12  115421.0
# 4              5  41.0    Male    Finance                12   27708.0
# ..           ...   ...     ...        ...               ...       ...
# 995          996  58.0    Male      Sales                13   78535.0
# 996          997  22.0  Female    Finance                15  119090.0
# 997          998   NaN    Male         IT                14   55908.0
# 998          999  38.0    Male      Sales                 3   77113.0
# 999         1000  47.0    Male    Finance                 6   44610.0
#
#      projects_completed  performance_score  satisfaction_level       city  \
# ...

# %%
df.head()
# Out:
#    employee_id   age  gender department  experience_years    salary  \
# 0            1  59.0  Female    Finance                13   52127.0
# 1            2   NaN    Male      Sales                15   30141.0
# 2            3  35.0    Male         HR                 0   53884.0
# 3            4  28.0  Female         HR                12  115421.0
# 4            5  41.0    Male    Finance                12   27708.0
#
#    projects_completed  performance_score  satisfaction_level       city  \
# 0                   7           3.028330            0.209273       Pune
# 1                   6           3.551607            0.749019  Bangalore
# 2                   2           4.940698            0.265406      Delhi
# 3                   8           4.072022            0.395547       Pune
# 4                   7           2.737446            0.538491    Chennai
#
#    work_hours_per_week promotion_last_5years
# 0                   54                    No
# ...

# %%
df.columns
# Out:
# Index(['employee_id', 'age', 'gender', 'department', 'experience_years',
#        'salary', 'projects_completed', 'performance_score',
#        'satisfaction_level', 'city', 'work_hours_per_week',
#        'promotion_last_5years'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 12)

# %%
sns.histplot(data=df,x='age',kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df,x='age',hue='gender',kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(data=df,y='age')
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(data=df,y='salary')
# Out:
# <Axes: ylabel='salary'>

# %%
sns.histplot(data=df,x='salary',kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.boxplot(data=df,y='salary',hue='gender')
# Out:
# <Axes: ylabel='salary'>

# %%
sns.kdeplot(data=df,x='salary',hue='gender')
# Out:
# <Axes: xlabel='salary', ylabel='Density'>

# %%
sns.barplot(data=df,y='experience_years',errorbar=('ci',95))
# Out:
# <Axes: ylabel='experience_years'>

# %%
df.head()
# Out:
#    employee_id   age  gender department  experience_years    salary  \
# 0            1  59.0  Female    Finance                13   52127.0
# 1            2   NaN    Male      Sales                15   30141.0
# 2            3  35.0    Male         HR                 0   53884.0
# 3            4  28.0  Female         HR                12  115421.0
# 4            5  41.0    Male    Finance                12   27708.0
#
#    projects_completed  performance_score  satisfaction_level       city  \
# 0                   7           3.028330            0.209273       Pune
# 1                   6           3.551607            0.749019  Bangalore
# 2                   2           4.940698            0.265406      Delhi
# 3                   8           4.072022            0.395547       Pune
# 4                   7           2.737446            0.538491    Chennai
#
#    work_hours_per_week promotion_last_5years
# 0                   54                    No
# ...

# %%
df.isna().sum()
# Out:
# employee_id               0
# age                      50
# gender                    0
# department                0
# experience_years          0
# salary                   50
# projects_completed        0
# performance_score         0
# satisfaction_level       50
# city                      0
# work_hours_per_week       0
# promotion_last_5years     0
# dtype: int64

# %%
df['experience_years'].mean()
# Out:
# 9.444

# %%
sns.countplot(data=df,x='experience_years')
# Out:
# <Axes: xlabel='experience_years', ylabel='count'>

# %%
df[df['experience_years']==12].shape
# Out:
# (64, 12)

# %%
sns.countplot(data=df,x='experience_years',hue='gender')
# Out:
# <Axes: xlabel='experience_years', ylabel='count'>

# %%
sns.countplot(data=df,x='satisfaction_level',hue='city')
# Out:
# <Axes: xlabel='satisfaction_level', ylabel='count'>

# %%
df.columns
# Out:
# Index(['employee_id', 'age', 'gender', 'department', 'experience_years',
#        'salary', 'projects_completed', 'performance_score',
#        'satisfaction_level', 'city', 'work_hours_per_week',
#        'promotion_last_5years'],
#       dtype='object')

# %%
plt.bar(df['experience_years'],df['salary'])
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.bar('experience_years','salary',data=df)
# Out:
# <BarContainer object of 1000 artists>

# %%
df['age'].isna().sum()
# Out:
# 50

# %%
data=df.groupby('gender')['performance_score'].mean()

# %%
data
# Out:
# gender
# Female    3.007337
# Male      2.952746
# Name: performance_score, dtype: float64

# %%
plt.pie(data.values,labels=data.index,autopct='%0.2f%%')
plt.show()

# %%
sns.scatterplot(data=df,x='age',y='salary')
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
sns.scatterplot(data=df,x='age',y='salary',hue='gender')
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
sns.regplot(data=df,x='age',y='salary')
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
x=[10,20,30,45,65,78,85,96,102]
y=list(range(0,9))

# %%
sns.regplot(x=y,y=x)
# Out:
# <Axes: >

# %%
sns.violinplot(data=df,y='age',hue='gender')
# Out:
# <Axes: ylabel='age'>

# %%
sns.jointplot(data=df,x='work_hours_per_week',y='performance_score') # top = hist, right = hist, middle = scatter

# %%
df.columns
# Out:
# Index(['employee_id', 'age', 'gender', 'department', 'experience_years',
#        'salary', 'projects_completed', 'performance_score',
#        'satisfaction_level', 'city', 'work_hours_per_week',
#        'promotion_last_5years'],
#       dtype='object')

# %%
sns.jointplot(data=df,x='work_hours_per_week',y='performance_score',hue='city')

# %%
sns.jointplot(data=df,x='work_hours_per_week',y='performance_score',hue='gender')

# %%
sns.scatterplot(data=df,x='salary',y='age')
# Out:
# <Axes: xlabel='salary', ylabel='age'>

# %%
sns.jointplot(data=df,x='salary',y='age',hue='performance_score')

# %%
df.isnull().sum()
# Out:
# employee_id               0
# age                      50
# gender                    0
# department                0
# experience_years          0
# salary                   50
# projects_completed        0
# performance_score         0
# satisfaction_level       50
# city                      0
# work_hours_per_week       0
# promotion_last_5years     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# employee_id              0
# age                      0
# gender                   0
# department               0
# experience_years         0
# salary                   0
# projects_completed       0
# performance_score        0
# satisfaction_level       0
# city                     0
# work_hours_per_week      0
# promotion_last_5years    0
# dtype: int64

# %%
df.head()
# Out:
#    employee_id   age  gender department  experience_years    salary  \
# 0            1  59.0  Female    Finance                13   52127.0
# 2            3  35.0    Male         HR                 0   53884.0
# 3            4  28.0  Female         HR                12  115421.0
# 4            5  41.0    Male    Finance                12   27708.0
# 5            6  59.0    Male  Marketing                 1   43375.0
#
#    projects_completed  performance_score  satisfaction_level       city  \
# 0                   7           3.028330            0.209273       Pune
# 2                   2           4.940698            0.265406      Delhi
# 3                   8           4.072022            0.395547       Pune
# 4                   7           2.737446            0.538491    Chennai
# 5                  11           2.785768            0.122288  Bangalore
#
#    work_hours_per_week promotion_last_5years
# 0                   54                    No
# ...

# %%
sns.jointplot(data=df,x='salary',y='projects_completed',hue='gender')

# %%
sns.jointplot(data=df,x='salary',y='age',hue='city')

# %%
df['performance_score']
# Out:
# 0      3.028330
# 2      4.940698
# 3      4.072022
# 4      2.737446
# 5      2.785768
#          ...
# 994    1.698359
# 995    3.829705
# 996    3.847112
# 998    3.330745
# 999    1.496429
# Name: performance_score, Length: 858, dtype: float64

# %%
sns.jointplot(data=df,x='salary',y='experience_years',hue='city')

# %%
sns.jointplot(data=df,x='age',y='performance_score',hue='gender')
